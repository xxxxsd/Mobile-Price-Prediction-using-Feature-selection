# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4688db7a-8316-419d-ab6e-5df6b5519dab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4688db7a-8316-419d-ab6e-5df6b5519dab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train_mobile_price.csv to train_mobile_price.csv

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
df=pd.read_csv("train_mobile_price.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0            842     0          2.2  ...             0     1            1
# 1           1021     1          0.5  ...             1     0            2
# 2            563     1          0.5  ...             1     0            2
# 3            615     1          2.5  ...             0     0            2
# 4           1821     1          1.2  ...             1     0            1
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        battery_power       blue  ...         wifi  price_range
# count    2000.000000  2000.0000  ...  2000.000000  2000.000000
# mean     1238.518500     0.4950  ...     0.507000     1.500000
# std       439.418206     0.5001  ...     0.500076     1.118314
# min       501.000000     0.0000  ...     0.000000     0.000000
# 25%       851.750000     0.0000  ...     0.000000     0.750000
# 50%      1226.000000     0.0000  ...     1.000000     1.500000
# 75%      1615.250000     1.0000  ...     1.000000     2.250000
# max      1998.000000     1.0000  ...     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
X=df.iloc[:,0:20]
Y=df.iloc[:,-1]

# %%
#SelectKBest to get top 10 features
Best_features=SelectKBest(score_func=chi2,k=10)
fit=Best_features.fit(X,Y)
fit.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
dfscores=pd.DataFrame(fit.scores_)

# %%
dfcolumns=pd.DataFrame(X.columns)

# %%
feature_scores=pd.concat([dfcolumns,dfscores],axis=1)
feature_scores.columns=['features','scores']

# %%
feature_scores.sort_values(by='scores',ascending=False)
# Out:
#          features         scores
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878
# 10             pc       9.186054
# 9         n_cores       9.097556
# 18   touch_screen       1.928429
# 5          four_g       1.521572
# 7           m_dep       0.745820
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 19           wifi       0.422091
# 17        three_g       0.327643

# %%
#Feature Importance

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
fit=clf.fit(X,Y)
fit.feature_importances_ *100
# Out:
# array([ 7.49723399,  0.68917412,  2.62614944,  0.71384247,  2.43301203,
#         0.5971312 ,  3.64261004,  2.40651939,  3.87373148,  2.24768943,
#         2.71813178,  5.68863334,  5.57588732, 49.05938814,  2.6999869 ,
#         2.78194039,  2.88425319,  0.53897056,  0.6904373 ,  0.63527751])

# %%
dframe=pd.DataFrame(fit.feature_importances_ *100)

final=pd.concat([dfcolumns,dframe],axis=1)
final.columns=['feature','Score']
final=final.sort_values(by='Score',ascending=False)

# %%
ten_features=final.head(n=10)['feature'].values
ten_features
# Out:
# array(['ram', 'battery_power', 'px_height', 'px_width', 'mobile_wt',
#        'int_memory', 'talk_time', 'sc_w', 'pc', 'sc_h'], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25,10))
plt.bar(final['feature'],final['Score'])
plt.show()

# %%
#This bar graph shows the importance of different features in descending order

# %%
df.corr()
# Out:
#                battery_power      blue  ...      wifi  price_range
# battery_power       1.000000  0.011252  ... -0.008343     0.200723
# blue                0.011252  1.000000  ... -0.021863     0.020573
# clock_speed         0.011482  0.021419  ... -0.024471    -0.006606
# dual_sim           -0.041847  0.035198  ...  0.022740     0.017444
# fc                  0.033334  0.003593  ...  0.020085     0.021998
# four_g              0.015665  0.013443  ... -0.017620     0.014772
# int_memory         -0.004004  0.041177  ...  0.006993     0.044435
# m_dep               0.034085  0.004049  ... -0.028353     0.000853
# mobile_wt           0.001844 -0.008605  ... -0.000409    -0.030302
# n_cores            -0.029727  0.036161  ... -0.009964     0.004399
# pc                  0.031441 -0.009952  ...  0.005389     0.033599
# px_height           0.014901 -0.006872  ...  0.051824     0.148858
# px_width           -0.008402 -0.041533  ...  0.030319     0.165818
# ...

# %%
#Correlation
import seaborn as sns
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)

# %%
#Calculating accuracy
from sklearn.model_selection import cross_val_score
clf=RandomForestClassifier(max_depth=10)
scores=cross_val_score(clf,X,Y,cv=10)

# %%
print(scores.mean()*100,"%")
# Out:
# 87.44999999999999 %

# %%
X
# Out:
#       battery_power  blue  clock_speed  ...  three_g  touch_screen  wifi
# 0               842     0          2.2  ...        0             0     1
# 1              1021     1          0.5  ...        1             1     0
# 2               563     1          0.5  ...        1             1     0
# 3               615     1          2.5  ...        1             0     0
# 4              1821     1          1.2  ...        1             1     0
# ...             ...   ...          ...  ...      ...           ...   ...
# 1995            794     1          0.5  ...        1             1     0
# 1996           1965     1          2.6  ...        1             1     1
# 1997           1911     0          0.9  ...        1             1     0
# 1998           1512     0          0.9  ...        1             1     1
# 1999            510     1          2.0  ...        1             1     1
#
# [2000 rows x 20 columns]

# %%
X[ten_features]
# Out:
#        ram  battery_power  px_height  px_width  ...  talk_time  sc_w  pc  sc_h
# 0     2549            842         20       756  ...         19     7   2     9
# 1     2631           1021        905      1988  ...          7     3   6    17
# 2     2603            563       1263      1716  ...          9     2   6    11
# 3     2769            615       1216      1786  ...         11     8   9    16
# 4     1411           1821       1208      1212  ...         15     2  14     8
# ...    ...            ...        ...       ...  ...        ...   ...  ..   ...
# 1995   668            794       1222      1890  ...         19     4  14    13
# 1996  2032           1965        915      1965  ...         16    10   3    11
# 1997  3057           1911        868      1632  ...          5     1   3     9
# 1998   869           1512        336       670  ...         19    10   5    18
# 1999  3919            510        483       754  ...          2     4  16    19
#
# ...

# %%
newscore=cross_val_score(clf,X[ten_features],Y,cv=10)
newscore
# Out:
# array([0.89 , 0.9  , 0.915, 0.91 , 0.9  , 0.925, 0.905, 0.905, 0.87 ,
#        0.93 ])

# %%
newscore.mean()
# Out:
# 0.9049999999999999

# %%
print(newscore.mean()*100,"%")
# Out:
# 90.49999999999999 %

# %% [markdown]
# The accuracy has considerably improved after Feature Selection.
